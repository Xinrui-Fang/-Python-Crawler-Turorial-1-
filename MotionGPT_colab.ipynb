# %% [markdown]
# <a href="https://colab.research.google.com/github/Xinrui-Fang/-Python-Crawler-Turorial-1-/blob/master/MotionGPT_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/MotionGPT-hf
# %cd /content/MotionGPT-hf

# !apt -y install -qq aria2 libosmesa6

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/assets/meta/mean_eval.npy -d /content/MotionGPT-hf/assets/meta -o mean_eval.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/assets/meta/mean.npy -d /content/MotionGPT-hf/assets/meta -o mean.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/assets/meta/std_eval.npy -d /content/MotionGPT-hf/assets/meta -o std_eval.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/assets/meta/std.npy -d /content/MotionGPT-hf/assets/meta -o std.npy
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/assets/videos/example0_blender.mp4 -d /content/MotionGPT-hf/assets/videos -o example0_blender.mp4
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/gmm_08.pkl -d /content/MotionGPT-hf/deps/smpl/smpl_models -o gmm_08.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/neutral_smpl_mean_params.h5 -d /content/MotionGPT-hf/deps/smpl/smpl_models -o neutral_smpl_mean_params.h5
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/SMPL_downsample_index.pkl -d /content/MotionGPT-hf/deps/smpl/smpl_models -o SMPL_downsample_index.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smpl.tar.gz -d /content/MotionGPT-hf/deps/smpl/smpl_models -o smpl.tar.gz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smpl/SMPL_FEMALE.pkl -d /content/MotionGPT-hf/deps/smpl/smpl_models/smpl -o SMPL_FEMALE.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smpl/SMPL_MALE.pkl -d /content/MotionGPT-hf/deps/smpl/smpl_models/smpl -o SMPL_MALE.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smpl/SMPL_NEUTRAL.pkl -d /content/MotionGPT-hf/deps/smpl/smpl_models/smpl -o SMPL_NEUTRAL.pkl
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/mano_v1_2.zip -d /content/MotionGPT-hf/deps/smpl/smpl_models/smplh -o mano_v1_2.zip
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/SMPLH_FEMALE.npz -d /content/MotionGPT-hf/deps/smpl/smpl_models/smplh -o SMPLH_FEMALE.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/SMPLH_MALE.npz -d /content/MotionGPT-hf/deps/smpl/smpl_models/smplh -o SMPLH_MALE.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/SMPLH_NEUTRAL.npz -d /content/MotionGPT-hf/deps/smpl/smpl_models/smplh -o SMPLH_NEUTRAL.npz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/smplh.tar.xz -d /content/MotionGPT-hf/deps/smpl/smpl_models/smplh -o smplh.tar.xz
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplx_parts_segm.pkl -d /content/MotionGPT-hf/deps/smpl/smpl_models -o smplx_parts_segm.pkl

import os
os.environ.pop("XDG_RUNTIME_DIR", None)
# Install compatible versions of numpy and chumpy
# !pip install numpy==1.21.6 chumpy==0.70

# Modify chumpy to remove deprecated imports from numpy
# !sed -i 's/from numpy import bool, int, float, complex, object, unicode, str, nan, inf/from numpy import nan, inf/g' /usr/local/lib/python3.10/dist-packages/chumpy/__init__.py

# !pip install -q gradio==3.50.2 pytorch-lightning omegaconf bert-score pyglet mapbox-earcut
# !pip install -q PyOpenGL_accelerate smplx trimesh triangle ftfy pyrender -U
# !pip install -q pyopengl==3.1.4 -U

# !pip install -q smplx==0.1.28 trimesh pyrender


# !python app.py
# Out:
# /content
# fatal: destination path 'MotionGPT-hf' already exists and is not an empty directory.
# /content/MotionGPT-hf
# aria2 is already the newest version (1.36.0-1).
# libosmesa6 is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 651f4d|OK  |       0B/s|/content/MotionGPT-hf/assets/meta/mean_eval.npy
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 97825b|OK  |       0B/s|/content/MotionGPT-hf/assets/meta/mean.npy
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0c14d1|OK  |       0B/s|/content/MotionGPT-hf/assets/meta/std_eval.npy
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# b566e5|OK  |       0B/s|/content/MotionGPT-hf/assets/meta/std.npy
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 7a96d2|OK  |       0B/s|/content/MotionGPT-hf/assets/videos/example0_blender.mp4
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 92a801|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/gmm_08.pkl
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0c5385|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/neutral_smpl_mean_params.h5
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 88d9f4|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/SMPL_downsample_index.pkl
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 10c3ed|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smpl.tar.gz
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a7c0d7|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smpl/SMPL_FEMALE.pkl
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6d43eb|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smpl/SMPL_MALE.pkl
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c896ec|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smpl/SMPL_NEUTRAL.pkl
#
# Status Legend:
# (OK):download completed.
#
# 11/01 13:07:27 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/mano_v1_2.zip
# Exception: [AbstractCommand.cc:351] errorCode=3 URI=https://huggingface.co/spaces/OpenMotionLab/MotionGPT/resolve/main/deps/smpl/smpl_models/smplh/mano_v1_2.zip
#   -> [HttpSkipResponseCommand.cc:218] errorCode=3 Resource not found
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# ea7387|ERR |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smplh/mano_v1_2.zip
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c5d6f3|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smplh/SMPLH_FEMALE.npz
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8d176a|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smplh/SMPLH_MALE.npz
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a97266|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smplh/SMPLH_NEUTRAL.npz
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 622b5f|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smplh/smplh.tar.xz
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# e76785|OK  |       0B/s|/content/MotionGPT-hf/deps/smpl/smpl_models/smplx_parts_segm.pkl
#
# Status Legend:
# (OK):download completed.
# Requirement already satisfied: numpy==1.21.6 in /usr/local/lib/python3.10/dist-packages (1.21.6)
# Requirement already satisfied: chumpy==0.70 in /usr/local/lib/python3.10/dist-packages (0.70)
# Requirement already satisfied: scipy>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from chumpy==0.70) (1.11.4)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from chumpy==0.70) (1.16.0)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrender 0.1.45 requires PyOpenGL==3.1.0, but you have pyopengl 3.1.4 which is incompatible.
# Seed set to 1234
# Fetching 3 files: 100% 3/3 [00:00<00:00, 40329.85it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /content/MotionGPT-hf/app.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f'{model_path}/motiongpt_s3_h3d.tar',
# /content/MotionGPT-hf/app.py:479: GradioDeprecationWarning: 'scale' value should be an integer. Using 0.85 will cause issues.
#   with gr.Column(scale=0.85):
# /content/MotionGPT-hf/app.py:510: GradioDeprecationWarning: 'scale' value should be an integer. Using 0.15 will cause issues.
#   with gr.Column(scale=0.15, min_width=150):
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://dcc39c082786de8fad.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ['A man is running']
# ['<motion_id_512><motion_id_180><motion_id_180><motion_id_180><motion_id_180><motion_id_180><motion_id_72><motion_id_360><motion_id_25><motion_id_427><motion_id_467><motion_id_352><motion_id_170><motion_id_499><motion_id_263><motion_id_383><motion_id_93><motion_id_180><motion_id_55><motion_id_433><motion_id_373><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/content/MotionGPT-hf/render.py", line 59, in <module>
#     render.init_renderer([shape[0], shape[1], 3], params)
#   File "/content/MotionGPT-hf/mGPT/render/pyrender/smpl_render.py", line 138, in init_renderer
#     self.renderer = Renderer(vertices=self.vertices, focal_length=self.focal_length,
#   File "/content/MotionGPT-hf/mGPT/render/pyrender/smpl_render.py", line 24, in __init__
#     self.renderer = pyrender.OffscreenRenderer(viewport_width=img_res[0],
#   File "/usr/local/lib/python3.10/dist-packages/pyrender/offscreen.py", line 31, in __init__
#     self._create()
#   File "/usr/local/lib/python3.10/dist-packages/pyrender/offscreen.py", line 149, in _create
#     self._platform.init_context()
#   File "/usr/local/lib/python3.10/dist-packages/pyrender/platforms/osmesa.py", line 19, in init_context
#     from OpenGL.osmesa import (
# ImportError: cannot import name 'OSMesaCreateContextAttribs' from 'OpenGL.osmesa' (/usr/local/lib/python3.10/dist-packages/OpenGL/osmesa/__init__.py)
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://dcc39c082786de8fad.gradio.live
# Keyboard interruption in main thread... closing server.
# ^C

# %%
# !pip install PyOpenGL==3.1.5 PyOpenGL-accelerate
# Out:
# Collecting PyOpenGL==3.1.5
#   Downloading PyOpenGL-3.1.5-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: PyOpenGL-accelerate in /usr/local/lib/python3.10/dist-packages (3.1.7)
# Downloading PyOpenGL-3.1.5-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 45.3 MB/s eta 0:00:00
# Installing collected packages: PyOpenGL
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.0
#     Uninstalling PyOpenGL-3.1.0:
#       Successfully uninstalled PyOpenGL-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyrender 0.1.45 requires PyOpenGL==3.1.0, but you have pyopengl 3.1.5 which is incompatible.
# Successfully installed PyOpenGL-3.1.5

# %%
# !apt-get install -y libosmesa6-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libdrm-dev libgl-dev libglx-dev libpciaccess-dev mesa-common-dev
# The following NEW packages will be installed:
#   libdrm-dev libgl-dev libglx-dev libosmesa6-dev libpciaccess-dev mesa-common-dev
# 0 upgraded, 6 newly installed, 0 to remove and 49 not upgraded.
# Need to get 2,646 kB of archives.
# After this operation, 5,899 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess-dev amd64 0.16-3 [21.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-dev amd64 2.4.113-2~ubuntu0.22.04.1 [292 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx-dev amd64 1.4.0-1 [14.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl-dev amd64 1.4.0-1 [101 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 mesa-common-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [2,208 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libosmesa6-dev amd64 23.2.1-1ubuntu3.1~22.04.2 [8,984 B]
# Fetched 2,646 kB in 2s (1,505 kB/s)
# Selecting previously unselected package libpciaccess-dev:amd64.
# (Reading database ... 123707 files and directories currently installed.)
# Preparing to unpack .../0-libpciaccess-dev_0.16-3_amd64.deb ...
# Unpacking libpciaccess-dev:amd64 (0.16-3) ...
# Selecting previously unselected package libdrm-dev:amd64.
# Preparing to unpack .../1-libdrm-dev_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libglx-dev:amd64.
# Preparing to unpack .../2-libglx-dev_1.4.0-1_amd64.deb ...
# Unpacking libglx-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package libgl-dev:amd64.
# Preparing to unpack .../3-libgl-dev_1.4.0-1_amd64.deb ...
# Unpacking libgl-dev:amd64 (1.4.0-1) ...
# Selecting previously unselected package mesa-common-dev:amd64.
# Preparing to unpack .../4-mesa-common-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Selecting previously unselected package libosmesa6-dev:amd64.
# Preparing to unpack .../5-libosmesa6-dev_23.2.1-1ubuntu3.1~22.04.2_amd64.deb ...
# Unpacking libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libpciaccess-dev:amd64 (0.16-3) ...
# Setting up libglx-dev:amd64 (1.4.0-1) ...
# Setting up libgl-dev:amd64 (1.4.0-1) ...
# Setting up libdrm-dev:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libosmesa6-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up mesa-common-dev:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
import os
os.environ["PYOPENGL_PLATFORM"] = "osmesa"

# %%
# !python app.py
# Out:
# Seed set to 1234
# Fetching 3 files: 100% 3/3 [00:00<00:00, 38245.93it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /content/MotionGPT-hf/app.py:35: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(f'{model_path}/motiongpt_s3_h3d.tar',
# /content/MotionGPT-hf/app.py:479: GradioDeprecationWarning: 'scale' value should be an integer. Using 0.85 will cause issues.
#   with gr.Column(scale=0.85):
# /content/MotionGPT-hf/app.py:510: GradioDeprecationWarning: 'scale' value should be an integer. Using 0.15 will cause issues.
#   with gr.Column(scale=0.15, min_width=150):
# Running on local URL:  http://127.0.0.1:7860
# IMPORTANT: You are using gradio version 3.50.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on public URL: https://18bbfb074c8dbd93a3.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ['the man is running']
# ['<motion_id_512><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_313><motion_id_170><motion_id_491><motion_id_78><motion_id_25><motion_id_500><motion_id_467><motion_id_352><motion_id_439><motion_id_383><motion_id_383><motion_id_28><motion_id_28><motion_id_28><motion_id_290><motion_id_383><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Moviepy - Building video cache/2024-11-01-13_13_4268067.mp4.
# Moviepy - Writing video cache/2024-11-01-13_13_4268067.mp4
#
# Moviepy - Done !
# Moviepy - video ready cache/2024-11-01-13_13_4268067.mp4
# ['The man is waving to me']
# ['<motion_id_512><motion_id_256><motion_id_423><motion_id_256><motion_id_369><motion_id_146><motion_id_146><motion_id_403><motion_id_403><motion_id_403><motion_id_91><motion_id_14><motion_id_281><motion_id_423><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Moviepy - Building video cache/2024-11-01-13_15_1344086.mp4.
# Moviepy - Writing video cache/2024-11-01-13_15_1344086.mp4
#
# Moviepy - Done !
# Moviepy - video ready cache/2024-11-01-13_15_1344086.mp4
# ['bowing to the author']
# ['<motion_id_512><motion_id_417><motion_id_300><motion_id_300><motion_id_93><motion_id_436><motion_id_406><motion_id_406><motion_id_406><motion_id_406><motion_id_406><motion_id_459><motion_id_240><motion_id_240><motion_id_240><motion_id_417><motion_id_417><motion_id_417><motion_id_256><motion_id_256><motion_id_417><motion_id_417><motion_id_417><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Moviepy - Building video cache/2024-11-01-13_22_3870620.mp4.
# Moviepy - Writing video cache/2024-11-01-13_22_3870620.mp4
#
# Moviepy - Done !
# Moviepy - video ready cache/2024-11-01-13_22_3870620.mp4
# ['the man returns back']
# ['<motion_id_512><motion_id_315><motion_id_447><motion_id_350><motion_id_259><motion_id_86><motion_id_127><motion_id_511><motion_id_72><motion_id_202><motion_id_47><motion_id_148><motion_id_264><motion_id_264><motion_id_264><motion_id_336><motion_id_420><motion_id_336><motion_id_189><motion_id_69><motion_id_510><motion_id_28><motion_id_127><motion_id_336><motion_id_264><motion_id_336><motion_id_306><motion_id_373><motion_id_373><motion_id_127><motion_id_336><motion_id_119><motion_id_375><motion_id_368><motion_id_264><motion_id_119><motion_id_264><motion_id_504><motion_id_250><motion_id_21><motion_id_450><motion_id_450><motion_id_43><motion_id_140><motion_id_140><motion_id_140><motion_id_260><motion_id_140><motion_id_135><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Moviepy - Building video cache/2024-11-01-13_39_4799460.mp4.
# Moviepy - Writing video cache/2024-11-01-13_39_4799460.mp4
#
# Moviepy - Done !
# Moviepy - video ready cache/2024-11-01-13_39_4799460.mp4
# ['the man is running']
# ['<motion_id_512><motion_id_325><motion_id_28><motion_id_28><motion_id_28><motion_id_505><motion_id_28><motion_id_326><motion_id_263><motion_id_192><motion_id_460><motion_id_395><motion_id_431><motion_id_176><motion_id_44><motion_id_39><motion_id_290><motion_id_395><motion_id_24><motion_id_24><motion_id_89><motion_id_359><motion_id_10><motion_id_128><motion_id_270><motion_id_367><motion_id_367><motion_id_128><motion_id_367><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Moviepy - Building video cache/2024-11-01-13_40_5792584.mp4.
# Moviepy - Writing video cache/2024-11-01-13_40_5792584.mp4
#
# Moviepy - Done !
# Moviepy - video ready cache/2024-11-01-13_40_5792584.mp4
# ['the man is running']
# ['<motion_id_512><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_28><motion_id_313><motion_id_170><motion_id_491><motion_id_78><motion_id_25><motion_id_500><motion_id_467><motion_id_352><motion_id_439><motion_id_383><motion_id_383><motion_id_28><motion_id_28><motion_id_28><motion_id_290><motion_id_383><motion_id_513>']
# error: XDG_RUNTIME_DIR not set in the environment.
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# ALSA lib confmisc.c:855:(parse_card) cannot find card '0'
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_card_inum returned error: No such file or directory
# ALSA lib confmisc.c:422:(snd_func_concat) error evaluating strings
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_concat returned error: No such file or directory
# ALSA lib confmisc.c:1334:(snd_func_refer) error evaluating name
# ALSA lib conf.c:5178:(_snd_config_evaluate) function snd_func_refer returned error: No such file or directory
# ALSA lib conf.c:5701:(snd_config_expand) Evaluate error: No such file or directory
# ALSA lib pcm.c:2664:(snd_pcm_open_noupdate) Unknown PCM default
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# Moviepy - Building video cache/2024-11-01-13_42_0442399.mp4.
# Moviepy - Writing video cache/2024-11-01-13_42_0442399.mp4
#
# Moviepy - Done !
# Moviepy - video ready cache/2024-11-01-13_42_0442399.mp4
